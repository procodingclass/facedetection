# %%
# Create_Database
import cv2, sys, numpy, os, time
count = 0
size = 4
fn_haar = 'haarcascade_frontalface_default.xml'
fn_dir = 'database'
fn_name = input("Enter the Person's Name: ")
path = os.path.join(fn_dir, fn_name)
if not os.path.isdir(path):
    os.mkdir(path)
(im_width, im_height) = (112, 92)
haar_cascade = cv2.CascadeClassifier(fn_haar)
webcam = cv2.VideoCapture(0)

print("-----------------------Taking pictures----------------------")
print("--------------------Give some expressions---------------------")

while count < 45:
    (rval, im) = webcam.read()
    im = cv2.flip(im, 1, 0)
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    mini = cv2.resize(gray,(gray.shape[1]//size, gray.shape[0]//size))
    faces = haar_cascade.detectMultiScale(mini)
    faces = sorted(faces, key=lambda x: x[3])
    if faces:
        face_i = faces[0]
        (x, y, w, h) = [v * size for v in face_i]
        face = gray[y:y + h, x:x + w]
        face_resize = cv2.resize(face, (im_width, im_height))
        pin=sorted([int(n[:n.find('.')]) for n in os.listdir(path)
               if n[0]!='.' ]+[0])[-1] + 1
        cv2.imwrite('%s/%s.png' % (path, pin), face_resize)
        cv2.rectangle(im, (x, y), (x + w, y + h), (0, 255, 0), 3)
        cv2.putText(im, fn_name, (x - 10, y - 10), cv2.FONT_HERSHEY_PLAIN,
            1,(0, 255, 0))
        time.sleep(0.38)
        count += 1
    cv2.imshow('OpenCV', im)
    key = cv2.waitKey(10)
    if key == 27:
        break
print(str(count) + " images taken and saved to " + fn_name +" folder in database ")
# Out:
# Enter the Person's Name:  omkar
# -----------------------Taking pictures----------------------
# --------------------Give some expressions---------------------
# 45 images taken and saved to omkar folder in database

# %%
import cv2, sys, numpy, os

size = 4
haar_file = 'haarcascade_frontalface_default.xml'
datasets = 'database1'

print('Training...')
# Create a list of images and a list of corresponding names
(images, lables, names, id) = ([], [], {}, 0)
for (subdirs, dirs, files) in os.walk(datasets):
    for subdir in dirs:
        names[id] = subdir
        subjectpath = os.path.join(datasets, subdir)
        print(subjectpath)
        for filename in os.listdir('database1/omkar'):
            path = subjectpath + '/' + filename
            lable = id
            images.append(cv2.imread(path, 0))
            lables.append(int(lable))
        id = 1
(width, height) = (130, 100)

# Create a Numpy array from the two lists above
(images, lables) = [numpy.array(lis) for lis in [images, lables]]

# OpenCV trains a model from the images
# NOTE FOR OpenCV2: remove '.face'
model = cv2.face.LBPHFaceRecognizer_create()
model.train(images, lables)

face_cascade = cv2.CascadeClassifier(haar_file)
webcam = cv2.VideoCapture(0)
while True:
    (_, im) = webcam.read()
    gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x, y, w, h) in faces:
        cv2.rectangle(im, (x, y), (x + w, y + h), (255, 0, 0), 2)
        face = gray[y:y + h, x:x + w]
        face_resize = cv2.resize(face, (width, height))
        # Try to recognize the face
        prediction = model.predict(face_resize)
        cv2.rectangle(im, (x, y), (x + w, y + h), (0, 255, 0), 3)

        if prediction[1] < 500:
            cv2.putText(im, '%s - %.0f' % (names[prediction[0]], prediction[1]), (x - 10, y - 10),
                        cv2.FONT_HERSHEY_PLAIN, 1, (0, 255, 0))
        else:
            cv2.putText(im, 'not recognized', (x - 10, y - 10), cv2.FONT_HERSHEY_PLAIN, 1, (0, 255, 0))

    cv2.imshow('OpenCV', im)
    if cv2.waitKey(1) & 0xFF ==ord('q'):
        break
        
webcam.release()
cv2.destroyAllWindows()
# Out:
# Training...
# database1/omkar
# database1/.ipynb_checkpoints
# [ WARN:0@223.292] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/8.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/9.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/14.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/28.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/29.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/15.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/17.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/16.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/12.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/13.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/39.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/11.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/10.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/38.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/35.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/21.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/20.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/34.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/22.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/36.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/37.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/23.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/27.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/33.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/32.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/26.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/18.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/30.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/24.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/25.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/31.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/19.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/.ipynb_checkpoints'): can't open/read file: check file path/integrity
# [ WARN:0@223.293] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/4.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.294] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/42.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.294] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/43.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.294] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/5.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.294] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/41.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.294] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/7.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.294] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/6.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.294] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/40.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.294] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/44.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.294] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/2.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.294] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/3.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.294] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/45.png'): can't open/read file: check file path/integrity
# [ WARN:0@223.294] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('database1/.ipynb_checkpoints/1.png'): can't open/read file: check file path/integrity
# /var/folders/gh/f09yqv_n7ln_vs1ysry_w2xc0000gn/T/ipykernel_30025/1899565139.py:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   (images, lables) = [numpy.array(lis) for lis in [images, lables]]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In [3], line 29
#      26 # OpenCV trains a model from the images
#      27 # NOTE FOR OpenCV2: remove '.face'
#      28 model = cv2.face.LBPHFaceRecognizer_create()
# ---> 29 model.train(images, lables)
#      31 face_cascade = cv2.CascadeClassifier(haar_file)
#      32 webcam = cv2.VideoCapture(0)
#
# error: OpenCV(4.6.0) /Users/runner/work/opencv-python/opencv-python/opencv/modules/core/src/matrix.cpp:246: error: (-215:Assertion failed) s >= 0 in function 'setSize'
